# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from numpy import mean
from numpy import std
from tensorflow.keras import layers
import tensorflow.keras as k
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from keras.utils import to_categorical
from matplotlib import pyplot
import datetime
# Out:
# /Users/paulmathai/.virtualenvs/keras_tf/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_file(filepath):
	dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
	return dataframe.values

# %%
# load a list of files into a 3D array of [samples, timesteps, features]
def load_group(filenames, prefix=''):
	loaded = list()
	for name in filenames:
		data = load_file(prefix + name)
		loaded.append(data)
	# stack group so that features are the 3rd dimension
	loaded = np.dstack(loaded)
	return loaded

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
	filepath = prefix + group + '/Inertial Signals/'
	# load all 9 files as a single array
	filenames = list()
	# total acceleration
	filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
	# body acceleration
	filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
	# body gyroscope
	filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
	# load input data
	X = load_group(filenames, filepath)
	# load class output
	y = load_file(prefix + group + '/y_'+group+'.txt')
	return X, y

# %%
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
	# load all train
	trainX, trainy = load_dataset_group('train', prefix + 'HARDataset/')
	print(trainX.shape, trainy.shape)
	# load all test
	testX, testy = load_dataset_group('test', prefix + 'HARDataset/')
	print(testX.shape, testy.shape)
	# zero-offset class values
	trainy = trainy - 1
	testy = testy - 1
	# one hot encode y
	trainy = tf.keras.utils.to_categorical(trainy)
	testy = tf.keras.utils.to_categorical(testy)
	print(trainX.shape, trainy.shape, testX.shape, testy.shape)
	return trainX, trainy, testX, testy

# %%
trainX, trainy, testX, testy = load_dataset()
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
# Out:
# (7352, 128, 9) (7352, 1)
# (2947, 128, 9) (2947, 1)
# (7352, 128, 9) (7352, 6) (2947, 128, 9) (2947, 6)

# %%
# reshape data into time steps of sub-sequences
n_steps, n_length = 4, 32
# define model
model = Sequential()
model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(Dropout(0.5)))
model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(100))
model.add(Dropout(0.5))
model.add(Dense(100, activation='relu'))
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summarize scores
def summarize_results(scores):
	print(scores)
	m, s = mean(scores), std(scores)
	print('Accuracy: %.3f%% (+/-%.3f)' % (m, s))

# %%
# run an experiment
scores = list()
def run_experiment(repeats=10):
	# load data
	trainX, trainy, testX, testy = load_dataset()
	# repeat experiment
	for r in range(repeats):
		score = evaluate_model(trainX, trainy, testX, testy, model)
		score = score * 100.0
		print('>#%d: %.3f' % (r+1, score))
		scores.append(score)

# %%
log_dir_cnn = "logs/fitcnn/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir_cnn, histogram_freq=1, update_freq = 2000)
def evaluate_model(trainX, trainy, testX, testy, model):
	# define model
	verbose, epochs, batch_size = 1, 25, 64
	n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
	trainX = trainX.reshape((trainX.shape[0], n_steps, n_length, n_features))
	testX = testX.reshape((testX.shape[0], n_steps, n_length, n_features))
    # fit network
	model.fit(trainX, trainy, epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=[tensorboard_callback])
	# evaluate model
	_, accuracy = model.evaluate(testX, testy, batch_size=batch_size, verbose=0)
	return accuracy

# %%
# run the experiment
run_experiment()
# summarize results
summarize_results(scores)
# Out:
# (7352, 128, 9) (7352, 1)
# (2947, 128, 9) (2947, 1)
# (7352, 128, 9) (7352, 6) (2947, 128, 9) (2947, 6)
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 16s 2ms/sample - loss: 0.6147 - accuracy: 0.7488
# Epoch 2/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.2294 - accuracy: 0.9139
# Epoch 3/25
# 7352/7352 [==============================] - 7s 992us/sample - loss: 0.1483 - accuracy: 0.9438
# Epoch 4/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.1344 - accuracy: 0.9459
# Epoch 5/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.1177 - accuracy: 0.9490
# Epoch 6/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.1130 - accuracy: 0.9510
# Epoch 7/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.1150 - accuracy: 0.9527
# Epoch 8/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.1074 - accuracy: 0.9529
# Epoch 9/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.1014 - accuracy: 0.9569
# Epoch 10/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.1187 - accuracy: 0.9483
# Epoch 11/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.1012 - accuracy: 0.9578
# Epoch 12/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0947 - accuracy: 0.9593
# Epoch 13/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0926 - accuracy: 0.9596
# Epoch 14/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.1022 - accuracy: 0.9565
# Epoch 15/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0982 - accuracy: 0.9555
# Epoch 16/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0890 - accuracy: 0.9595
# Epoch 17/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0818 - accuracy: 0.9640
# Epoch 18/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0767 - accuracy: 0.9649
# Epoch 19/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0821 - accuracy: 0.9619
# Epoch 20/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0679 - accuracy: 0.9665
# Epoch 21/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0718 - accuracy: 0.9655
# Epoch 22/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0792 - accuracy: 0.9661
# Epoch 23/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0661 - accuracy: 0.9660
# Epoch 24/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0618 - accuracy: 0.9693
# Epoch 25/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0624 - accuracy: 0.9701
# >#1: 91.788
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0657 - accuracy: 0.9686
# Epoch 2/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0688 - accuracy: 0.9679
# Epoch 3/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0685 - accuracy: 0.9691
# Epoch 4/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0608 - accuracy: 0.9701
# Epoch 5/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0593 - accuracy: 0.9713
# Epoch 6/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0584 - accuracy: 0.9712
# Epoch 7/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0543 - accuracy: 0.9728
# Epoch 8/25
# 7352/7352 [==============================] - 7s 1ms/sample - loss: 0.0515 - accuracy: 0.9736
# Epoch 9/25
# 7352/7352 [==============================] - 7s 992us/sample - loss: 0.0760 - accuracy: 0.9665
# Epoch 10/25
# 7352/7352 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.97 - 8s 1ms/sample - loss: 0.0600 - accuracy: 0.9709
# Epoch 11/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0592 - accuracy: 0.9702
# Epoch 12/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0508 - accuracy: 0.9714
# Epoch 13/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0486 - accuracy: 0.9751
# Epoch 14/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0549 - accuracy: 0.9759
# Epoch 15/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0513 - accuracy: 0.9755
# Epoch 16/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0470 - accuracy: 0.9765
# Epoch 17/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0456 - accuracy: 0.9777
# Epoch 18/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0559 - accuracy: 0.9754
# Epoch 19/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0422 - accuracy: 0.9788
# Epoch 20/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0399 - accuracy: 0.9788
# Epoch 21/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0399 - accuracy: 0.9804
# Epoch 22/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0394 - accuracy: 0.9807
# Epoch 23/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0490 - accuracy: 0.9784
# Epoch 24/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0369 - accuracy: 0.9835
# Epoch 25/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0391 - accuracy: 0.9812
# >#2: 91.788
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0347 - accuracy: 0.9833
# Epoch 2/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0463 - accuracy: 0.9788
# Epoch 3/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0410 - accuracy: 0.9820
# Epoch 4/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0302 - accuracy: 0.9864
# Epoch 5/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0373 - accuracy: 0.9835
# Epoch 6/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0327 - accuracy: 0.9857
# Epoch 7/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0279 - accuracy: 0.9853
# Epoch 8/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0456 - accuracy: 0.9822
# Epoch 9/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0412 - accuracy: 0.9816
# Epoch 10/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0369 - accuracy: 0.9838
# Epoch 11/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0305 - accuracy: 0.9865
# Epoch 12/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0325 - accuracy: 0.9863
# Epoch 13/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0427 - accuracy: 0.9805
# Epoch 14/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0318 - accuracy: 0.9864
# Epoch 15/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0311 - accuracy: 0.9872
# Epoch 16/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0284 - accuracy: 0.9883
# Epoch 17/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0297 - accuracy: 0.9856
# Epoch 18/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0227 - accuracy: 0.9902
# Epoch 19/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0271 - accuracy: 0.9882
# Epoch 20/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0276 - accuracy: 0.9880
# Epoch 21/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0261 - accuracy: 0.9880
# Epoch 22/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0226 - accuracy: 0.9905
# Epoch 23/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0190 - accuracy: 0.9908
# Epoch 24/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0204 - accuracy: 0.9918
# Epoch 25/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0168 - accuracy: 0.9921
# >#3: 91.856
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0307 - accuracy: 0.9869
# Epoch 2/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0328 - accuracy: 0.9872
# Epoch 3/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0257 - accuracy: 0.9883
# Epoch 4/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0260 - accuracy: 0.9890
# Epoch 5/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0156 - accuracy: 0.9935
# Epoch 6/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0209 - accuracy: 0.9912
# Epoch 7/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0245 - accuracy: 0.9898
# Epoch 8/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0363 - accuracy: 0.9850
# Epoch 9/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0358 - accuracy: 0.9846
# Epoch 10/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0186 - accuracy: 0.9914
# Epoch 11/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0309 - accuracy: 0.9876
# Epoch 12/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0156 - accuracy: 0.9942
# Epoch 13/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0159 - accuracy: 0.9935
# Epoch 14/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0243 - accuracy: 0.9901
# Epoch 15/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0189 - accuracy: 0.9918
# Epoch 16/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0192 - accuracy: 0.9922
# Epoch 17/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0181 - accuracy: 0.9925
# Epoch 18/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0139 - accuracy: 0.9940
# Epoch 19/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0132 - accuracy: 0.9952
# Epoch 20/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0215 - accuracy: 0.9913
# Epoch 21/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0115 - accuracy: 0.9955
# Epoch 22/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0127 - accuracy: 0.9947
# Epoch 23/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0209 - accuracy: 0.9922
# Epoch 24/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0234 - accuracy: 0.9906
# Epoch 25/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0315 - accuracy: 0.9903
# >#4: 90.397
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0205 - accuracy: 0.9925
# Epoch 2/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0183 - accuracy: 0.9929
# Epoch 3/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0111 - accuracy: 0.9952
# Epoch 4/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0187 - accuracy: 0.9925
# Epoch 5/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0159 - accuracy: 0.9918
# Epoch 6/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0114 - accuracy: 0.9947
# Epoch 7/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0087 - accuracy: 0.9965
# Epoch 8/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0177 - accuracy: 0.9936
# Epoch 9/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0136 - accuracy: 0.9956
# Epoch 10/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0087 - accuracy: 0.9963
# Epoch 11/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0215 - accuracy: 0.9922
# Epoch 12/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0143 - accuracy: 0.9946
# Epoch 13/25
# 7352/7352 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.99 - 12s 2ms/sample - loss: 0.0175 - accuracy: 0.9944
# Epoch 14/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0100 - accuracy: 0.9962
# Epoch 15/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0238 - accuracy: 0.9925
# Epoch 16/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0120 - accuracy: 0.9951
# Epoch 17/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0120 - accuracy: 0.9944
# Epoch 18/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0089 - accuracy: 0.9967
# Epoch 19/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0172 - accuracy: 0.9933
# Epoch 20/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0085 - accuracy: 0.9973
# Epoch 21/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0100 - accuracy: 0.9961
# Epoch 22/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0170 - accuracy: 0.9950
# Epoch 23/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0101 - accuracy: 0.9954
# Epoch 24/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0094 - accuracy: 0.9962
# Epoch 25/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0104 - accuracy: 0.9956
# >#5: 91.924
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 8s 1ms/sample - loss: 0.0083 - accuracy: 0.9970
# Epoch 2/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0077 - accuracy: 0.9965
# Epoch 3/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0238 - accuracy: 0.9912
# Epoch 4/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0118 - accuracy: 0.9961
# Epoch 5/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0070 - accuracy: 0.9969
# Epoch 6/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0232 - accuracy: 0.9931
# Epoch 7/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0074 - accuracy: 0.9969
# Epoch 8/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0155 - accuracy: 0.9937
# Epoch 9/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0178 - accuracy: 0.9925
# Epoch 10/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0144 - accuracy: 0.9947
# Epoch 11/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0116 - accuracy: 0.9952
# Epoch 12/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0072 - accuracy: 0.9967
# Epoch 13/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0123 - accuracy: 0.9950
# Epoch 14/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0100 - accuracy: 0.9963
# Epoch 15/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0046 - accuracy: 0.9976
# Epoch 16/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0168 - accuracy: 0.9931
# Epoch 17/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0079 - accuracy: 0.9966
# Epoch 18/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0060 - accuracy: 0.9984
# Epoch 19/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0056 - accuracy: 0.9978
# Epoch 20/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0040 - accuracy: 0.9984
# Epoch 21/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0112 - accuracy: 0.9962
# Epoch 22/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0183 - accuracy: 0.9932
# Epoch 23/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0052 - accuracy: 0.9977
# Epoch 24/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0044 - accuracy: 0.9984
# Epoch 25/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0184 - accuracy: 0.9943
# >#6: 92.806
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0072 - accuracy: 0.9969
# Epoch 2/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0163 - accuracy: 0.9944
# Epoch 3/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0057 - accuracy: 0.9978
# Epoch 4/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0074 - accuracy: 0.9967
# Epoch 5/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0149 - accuracy: 0.9956
# Epoch 6/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0148 - accuracy: 0.9954
# Epoch 7/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0128 - accuracy: 0.9956
# Epoch 8/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0049 - accuracy: 0.9988
# Epoch 9/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0040 - accuracy: 0.9989
# Epoch 10/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0043 - accuracy: 0.9989
# Epoch 11/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0064 - accuracy: 0.9981
# Epoch 12/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0088 - accuracy: 0.9970
# Epoch 13/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0071 - accuracy: 0.9974
# Epoch 14/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0148 - accuracy: 0.9956
# Epoch 15/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0073 - accuracy: 0.9980
# Epoch 16/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0020 - accuracy: 0.9997
# Epoch 17/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0094 - accuracy: 0.9974
# Epoch 18/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0095 - accuracy: 0.9970
# Epoch 19/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0029 - accuracy: 0.9992
# Epoch 20/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0035 - accuracy: 0.9995
# Epoch 21/25
# 7352/7352 [==============================] - 11s 1ms/sample - loss: 0.0119 - accuracy: 0.9966
# Epoch 22/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0101 - accuracy: 0.9967
# Epoch 23/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0043 - accuracy: 0.9992
# Epoch 24/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0013 - accuracy: 0.9996
# Epoch 25/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0093 - accuracy: 0.9970
# >#7: 93.315
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0097 - accuracy: 0.9970
# Epoch 2/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0129 - accuracy: 0.9963
# Epoch 3/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0218 - accuracy: 0.9951
# Epoch 4/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0113 - accuracy: 0.9973
# Epoch 5/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0120 - accuracy: 0.9955
# Epoch 6/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0092 - accuracy: 0.9961
# Epoch 7/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0051 - accuracy: 0.9984
# Epoch 8/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0086 - accuracy: 0.9973
# Epoch 9/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0074 - accuracy: 0.9977
# Epoch 10/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0124 - accuracy: 0.9963
# Epoch 11/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0120 - accuracy: 0.9970
# Epoch 12/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0085 - accuracy: 0.9971
# Epoch 13/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0028 - accuracy: 0.9993
# Epoch 14/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0022 - accuracy: 0.9993
# Epoch 15/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0015 - accuracy: 0.9995
# Epoch 16/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0016 - accuracy: 0.9997
# Epoch 17/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0022 - accuracy: 0.9995
# Epoch 18/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0074 - accuracy: 0.9977
# Epoch 19/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0022 - accuracy: 0.9995
# Epoch 20/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0019 - accuracy: 0.9995
# Epoch 21/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0046 - accuracy: 0.9980
# Epoch 22/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0111 - accuracy: 0.9963
# Epoch 23/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0047 - accuracy: 0.9986
# Epoch 24/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0030 - accuracy: 0.9992
# Epoch 25/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0068 - accuracy: 0.9984
# >#8: 92.365
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0038 - accuracy: 0.9992
# Epoch 2/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0110 - accuracy: 0.9965
# Epoch 3/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0149 - accuracy: 0.9950
# Epoch 4/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0075 - accuracy: 0.9976
# Epoch 5/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0044 - accuracy: 0.9992
# Epoch 6/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0017 - accuracy: 0.9996
# Epoch 7/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0055 - accuracy: 0.9980
# Epoch 8/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0066 - accuracy: 0.9982
# Epoch 9/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0018 - accuracy: 0.9995
# Epoch 10/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0208 - accuracy: 0.9937
# Epoch 11/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0042 - accuracy: 0.9985
# Epoch 12/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0157 - accuracy: 0.9946
# Epoch 13/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0125 - accuracy: 0.9961
# Epoch 14/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0112 - accuracy: 0.9973
# Epoch 15/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0108 - accuracy: 0.9978
# Epoch 16/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0111 - accuracy: 0.9969
# Epoch 17/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0085 - accuracy: 0.9971
# Epoch 18/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0024 - accuracy: 0.9990
# Epoch 19/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0014 - accuracy: 0.9996
# Epoch 20/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0103 - accuracy: 0.9970
# Epoch 21/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0073 - accuracy: 0.9981
# Epoch 22/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0051 - accuracy: 0.9984
# Epoch 23/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0059 - accuracy: 0.9988
# Epoch 24/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0048 - accuracy: 0.9985
# Epoch 25/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0041 - accuracy: 0.9988
# >#9: 93.315
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0037 - accuracy: 0.9990
# Epoch 2/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0114 - accuracy: 0.9958
# Epoch 3/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0026 - accuracy: 0.9993
# Epoch 4/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0022 - accuracy: 0.9992
# Epoch 5/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0086 - accuracy: 0.9966
# Epoch 6/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0033 - accuracy: 0.9990
# Epoch 7/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 9.9208e-04 - accuracy: 0.9999
# Epoch 8/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 8.7618e-04 - accuracy: 0.9997
# Epoch 9/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0106 - accuracy: 0.9969
# Epoch 10/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0041 - accuracy: 0.9985
# Epoch 11/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0023 - accuracy: 0.9993
# Epoch 12/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 9.7603e-04 - accuracy: 0.9997
# Epoch 13/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0069 - accuracy: 0.9986
# Epoch 14/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0037 - accuracy: 0.9990
# Epoch 15/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0039 - accuracy: 0.9989
# Epoch 16/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0027 - accuracy: 0.9992
# Epoch 17/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0084 - accuracy: 0.9978
# Epoch 18/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0080 - accuracy: 0.9981
# Epoch 19/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0043 - accuracy: 0.9989
# Epoch 20/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 6.3718e-04 - accuracy: 0.9997
# Epoch 21/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 6.1589e-04 - accuracy: 0.9999
# Epoch 22/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0017 - accuracy: 0.9997
# Epoch 23/25
# 7352/7352 [==============================] - 10s 1ms/sample - loss: 0.0123 - accuracy: 0.9965
# Epoch 24/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 0.0017 - accuracy: 0.9997
# Epoch 25/25
# 7352/7352 [==============================] - 9s 1ms/sample - loss: 2.1810e-04 - accuracy: 1.0000
# >#10: 92.229
# [91.78826212882996, 91.78826212882996, 91.85612201690674, 90.39701223373413, 91.923987865448, 92.80624389648438, 93.31523776054382, 92.36511588096619, 93.31523776054382, 92.22938418388367]
# Accuracy: 92.178% (+/-0.816)
