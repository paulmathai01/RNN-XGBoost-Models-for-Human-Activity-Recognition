# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from numpy import mean
from numpy import std
from tensorflow.keras import layers
import tensorflow.keras as k
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import ConvLSTM2D
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from keras.utils import to_categorical
from matplotlib import pyplot
import datetime
# Out:
# /Users/paulmathai/.virtualenvs/keras_tf/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_file(filepath):
	dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
	return dataframe.values

# %%
# load a list of files into a 3D array of [samples, timesteps, features]
def load_group(filenames, prefix=''):
	loaded = list()
	for name in filenames:
		data = load_file(prefix + name)
		loaded.append(data)
	# stack group so that features are the 3rd dimension
	loaded = np.dstack(loaded)
	return loaded

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
	filepath = prefix + group + '/Inertial Signals/'
	# load all 9 files as a single array
	filenames = list()
	# total acceleration
	filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
	# body acceleration
	filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
	# body gyroscope
	filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
	# load input data
	X = load_group(filenames, filepath)
	# load class output
	y = load_file(prefix + group + '/y_'+group+'.txt')
	return X, y

# %%
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
	# load all train
	trainX, trainy = load_dataset_group('train', prefix + 'HARDataset/')
	print(trainX.shape, trainy.shape)
	# load all test
	testX, testy = load_dataset_group('test', prefix + 'HARDataset/')
	print(testX.shape, testy.shape)
	# zero-offset class values
	trainy = trainy - 1
	testy = testy - 1
	# one hot encode y
	trainy = tf.keras.utils.to_categorical(trainy)
	testy = tf.keras.utils.to_categorical(testy)
	print(trainX.shape, trainy.shape, testX.shape, testy.shape)
	return trainX, trainy, testX, testy

# %%
trainX, trainy, testX, testy = load_dataset()
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
# Out:
# (7352, 128, 9) (7352, 1)
# (2947, 128, 9) (2947, 1)
# (7352, 128, 9) (7352, 6) (2947, 128, 9) (2947, 6)

# %%
# reshape into subsequences (samples, time steps, rows, cols, channels)
n_steps, n_length = 4, 32
# define model
model = Sequential()
model.add(ConvLSTM2D(filters=64, kernel_size=(1,3), activation='relu', input_shape=(n_steps, 1, n_length, n_features)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
log_dir_cnn = "logs/fitconv/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir_cnn, histogram_freq=1, update_freq = 2000)
def evaluate_model(trainX, trainy, testX, testy, model):
	# define model
	verbose, epochs, batch_size = 1, 25, 64
	n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
	# reshape into subsequences (samples, time steps, rows, cols, channels)
	n_steps, n_length = 4, 32
	trainX = trainX.reshape((trainX.shape[0], n_steps, 1, n_length, n_features))
	testX = testX.reshape((testX.shape[0], n_steps, 1, n_length, n_features))
	# fit network
	model.fit(trainX, trainy, epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=[tensorboard_callback])
	# evaluate model
	_, accuracy = model.evaluate(testX, testy, batch_size=batch_size, verbose=0)
	return accuracy

# %%
# summarize scores
def summarize_results(scores):
	print(scores)
	m, s = mean(scores), std(scores)
	print('Accuracy: %.3f%% (+/-%.3f)' % (m, s))

# %%
# run an experiment
scores = list()
def run_experiment(repeats=10):
	# load data
	trainX, trainy, testX, testy = load_dataset()
	# repeat experiment
	for r in range(repeats):
		score = evaluate_model(trainX, trainy, testX, testy, model)
		score = score * 100.0
		print('>#%d: %.3f' % (r+1, score))
		scores.append(score)

# %%
# run the experiment
run_experiment()
# summarize results
summarize_results(scores)
# Out:
# (7352, 128, 9) (7352, 1)
# (2947, 128, 9) (2947, 1)
# (7352, 128, 9) (7352, 6) (2947, 128, 9) (2947, 6)
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.6314 - accuracy: 0.7399
# Epoch 2/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.2359 - accuracy: 0.9091
# Epoch 3/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.1691 - accuracy: 0.9309
# Epoch 4/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.1361 - accuracy: 0.9421
# Epoch 5/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.1239 - accuracy: 0.9475
# Epoch 6/25
# 7352/7352 [==============================] - 16s 2ms/sample - loss: 0.1188 - accuracy: 0.9505
# Epoch 7/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.1263 - accuracy: 0.9490
# Epoch 8/25
# 7352/7352 [==============================] - 18s 3ms/sample - loss: 0.1185 - accuracy: 0.9498
# Epoch 9/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.1185 - accuracy: 0.9504
# Epoch 10/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.1061 - accuracy: 0.9540
# Epoch 11/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.1026 - accuracy: 0.9569
# Epoch 12/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.1005 - accuracy: 0.9566
# Epoch 13/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0967 - accuracy: 0.9570
# Epoch 14/25
# 7352/7352 [==============================] - 16s 2ms/sample - loss: 0.0968 - accuracy: 0.9570
# Epoch 15/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0922 - accuracy: 0.9606
# Epoch 16/25
# 7352/7352 [==============================] - 16s 2ms/sample - loss: 0.1063 - accuracy: 0.9558
# Epoch 17/25
# 7352/7352 [==============================] - 16s 2ms/sample - loss: 0.1012 - accuracy: 0.9572
# Epoch 18/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0849 - accuracy: 0.9612
# Epoch 19/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0812 - accuracy: 0.9630
# Epoch 20/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0906 - accuracy: 0.9584
# Epoch 21/25
# 7352/7352 [==============================] - 15s 2ms/sample - loss: 0.0785 - accuracy: 0.9629
# Epoch 22/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0755 - accuracy: 0.9631
# Epoch 23/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0759 - accuracy: 0.9644
# Epoch 24/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0862 - accuracy: 0.9642
# Epoch 25/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0717 - accuracy: 0.9626
# >#1: 91.619
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0685 - accuracy: 0.9661
# Epoch 2/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0683 - accuracy: 0.9659
# Epoch 3/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0695 - accuracy: 0.9668
# Epoch 4/25
# 7352/7352 [==============================] - 16s 2ms/sample - loss: 0.0649 - accuracy: 0.9694
# Epoch 5/25
# 7352/7352 [==============================] - 17s 2ms/sample - loss: 0.0630 - accuracy: 0.9695
# Epoch 6/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0578 - accuracy: 0.9714
# Epoch 7/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0677 - accuracy: 0.9691
# Epoch 8/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0606 - accuracy: 0.9710
# Epoch 9/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0623 - accuracy: 0.9678
# Epoch 10/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0571 - accuracy: 0.9736
# Epoch 11/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0539 - accuracy: 0.9733
# Epoch 12/25
# 7352/7352 [==============================] - 23s 3ms/sample - loss: 0.0525 - accuracy: 0.9752
# Epoch 13/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0664 - accuracy: 0.9721
# Epoch 14/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0589 - accuracy: 0.9728
# Epoch 15/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0557 - accuracy: 0.9727
# Epoch 16/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0539 - accuracy: 0.9763
# Epoch 17/25
# 7352/7352 [==============================] - 18s 3ms/sample - loss: 0.0491 - accuracy: 0.9744
# Epoch 18/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0463 - accuracy: 0.9778
# Epoch 19/25
# 7352/7352 [==============================] - 23s 3ms/sample - loss: 0.0491 - accuracy: 0.9754
# Epoch 20/25
# 7352/7352 [==============================] - 23s 3ms/sample - loss: 0.0464 - accuracy: 0.9777
# Epoch 21/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0482 - accuracy: 0.9791
# Epoch 22/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0545 - accuracy: 0.9761
# Epoch 23/25
# 7352/7352 [==============================] - 23s 3ms/sample - loss: 0.0413 - accuracy: 0.9815
# Epoch 24/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0433 - accuracy: 0.9796
# Epoch 25/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0392 - accuracy: 0.9811
# >#2: 90.092
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0448 - accuracy: 0.9774
# Epoch 2/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0455 - accuracy: 0.9793
# Epoch 3/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0392 - accuracy: 0.9827
# Epoch 4/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0385 - accuracy: 0.9825
# Epoch 5/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0409 - accuracy: 0.9823
# Epoch 6/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0470 - accuracy: 0.9796
# Epoch 7/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0374 - accuracy: 0.9822
# Epoch 8/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0426 - accuracy: 0.9799
# Epoch 9/25
# 7352/7352 [==============================] - 25s 3ms/sample - loss: 0.0440 - accuracy: 0.9804
# Epoch 10/25
# 7352/7352 [==============================] - 24s 3ms/sample - loss: 0.0379 - accuracy: 0.9822
# Epoch 11/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0384 - accuracy: 0.9833
# Epoch 12/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0348 - accuracy: 0.9845
# Epoch 13/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0408 - accuracy: 0.9830
# Epoch 14/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0359 - accuracy: 0.9844
# Epoch 15/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0306 - accuracy: 0.9864
# Epoch 16/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0305 - accuracy: 0.9863
# Epoch 17/25
# 7352/7352 [==============================] - 23s 3ms/sample - loss: 0.0309 - accuracy: 0.9863
# Epoch 18/25
# 7352/7352 [==============================] - 23s 3ms/sample - loss: 0.0322 - accuracy: 0.9852
# Epoch 19/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0317 - accuracy: 0.9867
# Epoch 20/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0271 - accuracy: 0.9882
# Epoch 21/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0299 - accuracy: 0.9871
# Epoch 22/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0247 - accuracy: 0.9895
# Epoch 23/25
# 7352/7352 [==============================] - 27s 4ms/sample - loss: 0.0277 - accuracy: 0.9872
# Epoch 24/25
# 7352/7352 [==============================] - 24s 3ms/sample - loss: 0.0328 - accuracy: 0.9883
# Epoch 25/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0464 - accuracy: 0.9835
# >#3: 90.533
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0242 - accuracy: 0.9890
# Epoch 2/25
# 7352/7352 [==============================] - 24s 3ms/sample - loss: 0.0266 - accuracy: 0.9883
# Epoch 3/25
# 7352/7352 [==============================] - 24s 3ms/sample - loss: 0.0281 - accuracy: 0.9872
# Epoch 4/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0259 - accuracy: 0.9891
# Epoch 5/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0233 - accuracy: 0.9902
# Epoch 6/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0328 - accuracy: 0.9887
# Epoch 7/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0265 - accuracy: 0.9897
# Epoch 8/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0276 - accuracy: 0.9875
# Epoch 9/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0240 - accuracy: 0.9898
# Epoch 10/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0251 - accuracy: 0.9888
# Epoch 11/25
# 7352/7352 [==============================] - 22s 3ms/sample - loss: 0.0243 - accuracy: 0.9894
# Epoch 12/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0196 - accuracy: 0.9905
# Epoch 13/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0223 - accuracy: 0.9909
# Epoch 14/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0221 - accuracy: 0.9910
# Epoch 15/25
# 7352/7352 [==============================] - 18s 3ms/sample - loss: 0.0234 - accuracy: 0.9902
# Epoch 16/25
# 7352/7352 [==============================] - 18s 3ms/sample - loss: 0.0171 - accuracy: 0.9922
# Epoch 17/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0216 - accuracy: 0.9910
# Epoch 18/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0233 - accuracy: 0.9914
# Epoch 19/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0292 - accuracy: 0.9898
# Epoch 20/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0437 - accuracy: 0.9876
# Epoch 21/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0198 - accuracy: 0.9922
# Epoch 22/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0213 - accuracy: 0.9914
# Epoch 23/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0223 - accuracy: 0.9898
# Epoch 24/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0251 - accuracy: 0.9920
# Epoch 25/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0180 - accuracy: 0.9928
# >#4: 91.619
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0165 - accuracy: 0.9929
# Epoch 2/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0183 - accuracy: 0.9933
# Epoch 3/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0205 - accuracy: 0.9913
# Epoch 4/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0175 - accuracy: 0.9925
# Epoch 5/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0164 - accuracy: 0.9942
# Epoch 6/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0210 - accuracy: 0.9913
# Epoch 7/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0163 - accuracy: 0.9937
# Epoch 8/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0204 - accuracy: 0.9931
# Epoch 9/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0204 - accuracy: 0.9920
# Epoch 10/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0149 - accuracy: 0.9947
# Epoch 11/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0175 - accuracy: 0.9935
# Epoch 12/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0185 - accuracy: 0.9921
# Epoch 13/25
# 7352/7352 [==============================] - 18s 2ms/sample - loss: 0.0202 - accuracy: 0.9925
# Epoch 14/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0130 - accuracy: 0.9951
# Epoch 15/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0144 - accuracy: 0.9947
# Epoch 16/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0123 - accuracy: 0.9944
# Epoch 17/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0213 - accuracy: 0.9936
# Epoch 18/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0151 - accuracy: 0.9937
# Epoch 19/25
# 7352/7352 [==============================] - 21s 3ms/sample - loss: 0.0173 - accuracy: 0.9943
# Epoch 20/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0116 - accuracy: 0.9958
# Epoch 21/25
# 7352/7352 [==============================] - 19s 3ms/sample - loss: 0.0118 - accuracy: 0.9965
# Epoch 22/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0124 - accuracy: 0.9966
# Epoch 23/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0146 - accuracy: 0.9944
# Epoch 24/25
# 7352/7352 [==============================] - 20s 3ms/sample - loss: 0.0176 - accuracy: 0.9932
# Epoch 25/25
# 7352/7352 [==============================] - 16s 2ms/sample - loss: 0.0134 - accuracy: 0.9933
# >#5: 91.347
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0133 - accuracy: 0.9955
# Epoch 2/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0141 - accuracy: 0.9943
# Epoch 3/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0202 - accuracy: 0.9940
# Epoch 4/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0123 - accuracy: 0.9959
# Epoch 5/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0135 - accuracy: 0.9940
# Epoch 6/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0122 - accuracy: 0.9954
# Epoch 7/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0157 - accuracy: 0.9946
# Epoch 8/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0133 - accuracy: 0.9944
# Epoch 9/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0088 - accuracy: 0.9969
# Epoch 10/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0094 - accuracy: 0.9969
# Epoch 11/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0084 - accuracy: 0.9963
# Epoch 12/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0107 - accuracy: 0.9961
# Epoch 13/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0075 - accuracy: 0.9970
# Epoch 14/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0108 - accuracy: 0.9959
# Epoch 15/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0129 - accuracy: 0.9950
# Epoch 16/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0311 - accuracy: 0.9890
# Epoch 17/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0145 - accuracy: 0.9956
# Epoch 18/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0098 - accuracy: 0.9962
# Epoch 19/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0100 - accuracy: 0.9952
# Epoch 20/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0242 - accuracy: 0.9903
# Epoch 21/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0059 - accuracy: 0.9988
# Epoch 22/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0075 - accuracy: 0.9969
# Epoch 23/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0064 - accuracy: 0.9977
# Epoch 24/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0118 - accuracy: 0.9948
# Epoch 25/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0111 - accuracy: 0.9961
# >#6: 91.992
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0095 - accuracy: 0.9959
# Epoch 2/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0069 - accuracy: 0.9969
# Epoch 3/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0067 - accuracy: 0.9976
# Epoch 4/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0156 - accuracy: 0.9961
# Epoch 5/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0087 - accuracy: 0.9966
# Epoch 6/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0138 - accuracy: 0.9936
# Epoch 7/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0071 - accuracy: 0.9977
# Epoch 8/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0064 - accuracy: 0.9978
# Epoch 9/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0083 - accuracy: 0.9976
# Epoch 10/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0058 - accuracy: 0.9977
# Epoch 11/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0046 - accuracy: 0.9982
# Epoch 12/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0106 - accuracy: 0.9956
# Epoch 13/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0185 - accuracy: 0.9928
# Epoch 14/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0057 - accuracy: 0.9984
# Epoch 15/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0037 - accuracy: 0.9993
# Epoch 16/25
# 7352/7352 [==============================] - 15s 2ms/sample - loss: 0.0074 - accuracy: 0.9973
# Epoch 17/25
# 7352/7352 [==============================] - 15s 2ms/sample - loss: 0.0090 - accuracy: 0.9970
# Epoch 18/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0085 - accuracy: 0.9967
# Epoch 19/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0047 - accuracy: 0.9984
# Epoch 20/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0085 - accuracy: 0.9974
# Epoch 21/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0052 - accuracy: 0.9978
# Epoch 22/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0104 - accuracy: 0.9965
# Epoch 23/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0088 - accuracy: 0.9961
# Epoch 24/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0051 - accuracy: 0.9982
# Epoch 25/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0069 - accuracy: 0.9976
# >#7: 92.535
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0228 - accuracy: 0.9946
# Epoch 2/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0210 - accuracy: 0.9944
# Epoch 3/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0135 - accuracy: 0.9963
# Epoch 4/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0107 - accuracy: 0.9965
# Epoch 5/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0072 - accuracy: 0.9971
# Epoch 6/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0049 - accuracy: 0.9985
# Epoch 7/25
# 7352/7352 [==============================] - 11s 2ms/sample - loss: 0.0048 - accuracy: 0.9986
# Epoch 8/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0050 - accuracy: 0.9980
# Epoch 9/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0038 - accuracy: 0.9985
# Epoch 10/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0143 - accuracy: 0.9956
# Epoch 11/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0128 - accuracy: 0.9966
# Epoch 12/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0041 - accuracy: 0.9989
# Epoch 13/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0042 - accuracy: 0.9986
# Epoch 14/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0038 - accuracy: 0.9986
# Epoch 15/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0049 - accuracy: 0.9985
# Epoch 16/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0065 - accuracy: 0.9977
# Epoch 17/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0267 - accuracy: 0.9961
# Epoch 18/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0135 - accuracy: 0.9951
# Epoch 19/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0071 - accuracy: 0.9976
# Epoch 20/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0038 - accuracy: 0.9989
# Epoch 21/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0030 - accuracy: 0.9992
# Epoch 22/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0043 - accuracy: 0.9984
# Epoch 23/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0045 - accuracy: 0.9977
# Epoch 24/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0076 - accuracy: 0.9970
# Epoch 25/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0063 - accuracy: 0.9978
# >#8: 91.958
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0040 - accuracy: 0.9988
# Epoch 2/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0041 - accuracy: 0.9986
# Epoch 3/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0040 - accuracy: 0.9984
# Epoch 4/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0069 - accuracy: 0.9973
# Epoch 5/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0046 - accuracy: 0.9989
# Epoch 6/25
# 7352/7352 [==============================] - 15s 2ms/sample - loss: 0.0104 - accuracy: 0.9966
# Epoch 7/25
# 7352/7352 [==============================] - 15s 2ms/sample - loss: 0.0109 - accuracy: 0.9959
# Epoch 8/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0148 - accuracy: 0.9969
# Epoch 9/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0059 - accuracy: 0.9982
# Epoch 10/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0070 - accuracy: 0.9977
# Epoch 11/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0087 - accuracy: 0.9969
# Epoch 12/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0051 - accuracy: 0.9981
# Epoch 13/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0039 - accuracy: 0.9981
# Epoch 14/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0048 - accuracy: 0.9985
# Epoch 15/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0079 - accuracy: 0.9966
# Epoch 16/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0033 - accuracy: 0.9989
# Epoch 17/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0065 - accuracy: 0.9980
# Epoch 18/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0086 - accuracy: 0.9970
# Epoch 19/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0092 - accuracy: 0.9962
# Epoch 20/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0078 - accuracy: 0.9970
# Epoch 21/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0032 - accuracy: 0.9990
# Epoch 22/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0046 - accuracy: 0.9986
# Epoch 23/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0052 - accuracy: 0.9980
# Epoch 24/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0037 - accuracy: 0.9988
# Epoch 25/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0119 - accuracy: 0.9966
# >#9: 91.347
# Train on 7352 samples
# Epoch 1/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0102 - accuracy: 0.9969
# Epoch 2/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0147 - accuracy: 0.9962
# Epoch 3/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0031 - accuracy: 0.9990
# Epoch 4/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0065 - accuracy: 0.9977
# Epoch 5/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0032 - accuracy: 0.9990
# Epoch 6/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0027 - accuracy: 0.9993
# Epoch 7/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0064 - accuracy: 0.9977
# Epoch 8/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0128 - accuracy: 0.9955
# Epoch 9/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0061 - accuracy: 0.9982
# Epoch 10/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0027 - accuracy: 0.9989
# Epoch 11/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0035 - accuracy: 0.9988
# Epoch 12/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0027 - accuracy: 0.9990
# Epoch 13/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0028 - accuracy: 0.9990
# Epoch 14/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0052 - accuracy: 0.9977
# Epoch 15/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0044 - accuracy: 0.9985
# Epoch 16/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0042 - accuracy: 0.9986
# Epoch 17/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0015 - accuracy: 0.9997
# Epoch 18/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0017 - accuracy: 0.9995
# Epoch 19/25
# 7352/7352 [==============================] - 13s 2ms/sample - loss: 0.0043 - accuracy: 0.9986
# Epoch 20/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0058 - accuracy: 0.9978
# Epoch 21/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0115 - accuracy: 0.9956
# Epoch 22/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0142 - accuracy: 0.9950
# Epoch 23/25
# 7352/7352 [==============================] - 12s 2ms/sample - loss: 0.0041 - accuracy: 0.9984
# Epoch 24/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0069 - accuracy: 0.9973
# Epoch 25/25
# 7352/7352 [==============================] - 14s 2ms/sample - loss: 0.0037 - accuracy: 0.9986
# >#10: 91.788
# [91.6185975074768, 90.09161591529846, 90.53274393081665, 91.6185975074768, 91.34713411331177, 91.99185371398926, 92.53478050231934, 91.95792078971863, 91.34713411331177, 91.78826212882996]
# Accuracy: 91.483% (+/-0.678)
